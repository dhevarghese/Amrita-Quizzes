# %% [markdown]
# <a href="https://colab.research.google.com/github/ColdCoffee21/Amrita-Quizzes/blob/master/Introduction_to_handling_missing_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Session 5

# %% [markdown]
# ###Missing values

# %%
import numpy as np

# %%
missing_values=['--','na','n/a']
df6 = pd.read_csv('https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv', na_values=missing_values)
df6
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df6['OWN_OCCUPIED'] = df6['OWN_OCCUPIED'].replace(r'[0-9]+',np.nan,regex=True)
df6
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df6['NUM_BATH'] = df6['NUM_BATH'].replace(r'[A-Z]+',np.nan,regex=True)
df6
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0      NaN   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df6.isnull().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    3
# NUM_BATH        2
# SQ_FT           2
# dtype: int64

# %%
df6.isnull().sum().sum()
# Out:
# 12

# %%
#fillna() - you could give val, backward fill, forward fill
df6.fillna(0)
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     0.0
# 2  100003000.0     0.0   LEXINGTON            N           0.0        1   850.0
# 3  100004000.0   201.0    BERKELEY            0           1.0        0   700.0
# 4          0.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           0.0        1   800.0
# 6  100007000.0     0.0  WASHINGTON            0           2.0        0   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     0.0
# 8  100009000.0   215.0     TREMONT            Y           0.0        2  1800.0

# %%
df6
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0      NaN   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
#using backward fill, if last value is missing it wont get filled
df6.fillna(method='bfill')
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   850.0
# 2  100003000.0   201.0   LEXINGTON            N           1.0        1   850.0
# 3  100004000.0   201.0    BERKELEY            Y           1.0        2   700.0
# 4  100006000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           2.0        1   800.0
# 6  100007000.0   213.0  WASHINGTON            Y           2.0        1   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1  1800.0
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df6.fillna(method='ffill')
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5  1000.0
# 2  100003000.0   197.0   LEXINGTON            N           3.0        1   850.0
# 3  100004000.0   201.0    BERKELEY            N           1.0        1   700.0
# 4  100004000.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           3.0        1   800.0
# 6  100007000.0   207.0  WASHINGTON            Y           2.0        1   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1   950.0
# 8  100009000.0   215.0     TREMONT            Y           1.0        2  1800.0

# %%
df6.replace(to_replace=np.nan, value= -99) #same as fillna(-99)
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5   -99.0
# 2  100003000.0   -99.0   LEXINGTON            N         -99.0        1   850.0
# 3  100004000.0   201.0    BERKELEY          -99           1.0      -99   700.0
# 4        -99.0   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y         -99.0        1   800.0
# 6  100007000.0   -99.0  WASHINGTON          -99           2.0      -99   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1   -99.0
# 8  100009000.0   215.0     TREMONT            Y         -99.0        2  1800.0

# %%
df6.dropna() #no parameters - if there are nan values, the row will get deleted
# Out:
#            PID  ST_NUM ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0  PUTNAM            Y           3.0        1  1000.0

# %%
df6.dropna(how='all') #if the row fully consists of nan values, the row gets deleted
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0      NaN   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
df6.dropna(axis=1) #drop columnwise, if nan value present
# Out:
#       ST_NAME
# 0      PUTNAM
# 1   LEXINGTON
# 2   LEXINGTON
# 3    BERKELEY
# 4    BERKELEY
# 5    BERKELEY
# 6  WASHINGTON
# 7     TREMONT
# 8     TREMONT

# %%
new_data = df6.dropna(axis=0, how='any')

# %%
data_set = pd.read_csv("https://gist.githubusercontent.com/ktisha/c21e73a1bd1700294ef790c56c8aec1f/raw/819b69b5736821ccee93d05b51de0510bea00294/pima-indians-diabetes.csv", skiprows=9, header=None)

# %%
data_set
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0
#
# [768 rows x 9 columns]

# %%
data_set[[1,2,3,4,5]]=data_set[[1,2,3,4,5]].replace(0,np.nan)
print(data_set.isnull().sum())
# Out:
# 0      0
# 1      5
# 2     35
# 3    227
# 4    374
# 5     11
# 6      0
# 7      0
# 8      0
# dtype: int64

# %%
data_set.head()
# Out:
#    0      1     2     3      4     5      6   7  8
# 0  6  148.0  72.0  35.0    NaN  33.6  0.627  50  1
# 1  1   85.0  66.0  29.0    NaN  26.6  0.351  31  0
# 2  8  183.0  64.0   NaN    NaN  23.3  0.672  32  1
# 3  1   89.0  66.0  23.0   94.0  28.1  0.167  21  0
# 4  0  137.0  40.0  35.0  168.0  43.1  2.288  33  1

# %%
data_set.fillna(data_set.mean(),inplace=True)

# %%
data_set
# Out:
#       0      1     2         3           4     5      6   7  8
# 0     6  148.0  72.0  35.00000  155.548223  33.6  0.627  50  1
# 1     1   85.0  66.0  29.00000  155.548223  26.6  0.351  31  0
# 2     8  183.0  64.0  29.15342  155.548223  23.3  0.672  32  1
# 3     1   89.0  66.0  23.00000   94.000000  28.1  0.167  21  0
# 4     0  137.0  40.0  35.00000  168.000000  43.1  2.288  33  1
# ..   ..    ...   ...       ...         ...   ...    ...  .. ..
# 763  10  101.0  76.0  48.00000  180.000000  32.9  0.171  63  0
# 764   2  122.0  70.0  27.00000  155.548223  36.8  0.340  27  0
# 765   5  121.0  72.0  23.00000  112.000000  26.2  0.245  30  0
# 766   1  126.0  60.0  29.15342  155.548223  30.1  0.349  47  1
# 767   1   93.0  70.0  31.00000  155.548223  30.4  0.315  23  0
#
# [768 rows x 9 columns]
